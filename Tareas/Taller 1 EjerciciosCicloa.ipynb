# %% [markdown]
# Yanelis Correa -
# Newton Mercado

# %%
x= float(input())
n= int(input())
a=1

def factorial(x):
  factorial=1
  for i in range(1,x+1):
    factorial=factorial*i
  return factorial

for i in range(2,n+1):
  if i%2==0:
    Cosx = a + (((-1)**i) * (x**(2*i)))/ (factorial(2*i))
print("Cos x= ", Cosx)
# Out:
# 1
# 3
# Cos x=  1.0416666666666667

# %%
def factorial(x):
  factorial=1
  for k in range(1,x+1):
    factorial=factorial*k
  return factorial

x=float(input())
#e=float(input())
if e==0 or e<0:
  print("el epsilo es incorrecto")
k=int(input())
senx=0
while (abs(x**(2*k+1))/factorial(2*k+1)) > 0.01:
  if k%2!=0:
   senx = x +(((-1)k) * (x(2*k+1)))/ (factorial(2*k+1))
print("sen x= ", senx)
# Out:
#   File "<ipython-input-1-e88bba617fb1>", line 15
#     senx = x +(((-1)k) * (x(2*k+1)))/ (factorial(2*k+1))
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
