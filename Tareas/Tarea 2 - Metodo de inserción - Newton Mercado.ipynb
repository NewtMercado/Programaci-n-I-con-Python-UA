# %% [markdown]
# # Metodo de inserción

# %% [markdown]
# Mas efectivo es el 2do hecho, ya que empieza a iterar desde atras

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Metodo para lista

# %%
# Metodo de Ordenacion:
def MetodoInsercion(A):
  key= " "
  j=2
  for j in range(len(A)):
    key= A[j]
    i=j-1
    while i > 0 and A[i]>key:
      A[i+1]=A[i]
      i=i-1
    A[i+1]=key
  return A

# %%
A= [5, 2, 4, 6, 1, 3]
MetodoInsercion(A)
Numero = A[0]
del A[0]
A.append(Numero)
MetodoInsercion(A)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
A= [2, 4, 1, 3, 6]
MetodoInsercion(A)
Numero = A[0]
del A[0]
A.append(Numero)
MetodoInsercion(A)
# Out:
# [1, 2, 3, 4, 6]

# %% [markdown]
# ## Metodo para array

# %%
# Metodo de Ordenacion:
def MetodoOrdenacion(A):
  Longitud= len(A)
  for i in range(1, Longitud):
    ValorInsertado = A[i]
    ValorIndiceInsertar = i

    while ValorIndiceInsertar > 0 and A[ValorIndiceInsertar - 1] > ValorInsertado:
      # Se define el espacio para hacer la inserción:
      A[ValorIndiceInsertar] = A[ValorIndiceInsertar - 1]
      # Se actualiza la variable:
      ValorIndiceInsertar = ValorIndiceInsertar-1
      # Inserción del el valor en el indice:
      A[ValorIndiceInsertar] = ValorInsertado
  return A

# %%
A= [2, 4, 1, 3, 6]
MetodoOrdenacion(A)
# Out:
# [1, 2, 3, 4, 6]

# %% [markdown]
# # Otros

# %%
A= [5, 2, 4, 6, 1, 3]
key= " "
j=2
for j in range(len(A)):
  key= A[j]
  i=j-1
  while i > 0 and A[i]>key:
    A[i+1]=A[i]
    i=i-1
  A[i+1]=key
  print(A)
# Out:
# [5, 2, 4, 6, 1, 3]
# [5, 2, 4, 6, 1, 3]
# [5, 2, 4, 6, 1, 3]
# [5, 2, 4, 6, 1, 3]
# [5, 1, 2, 4, 6, 3]
# [5, 1, 2, 3, 4, 6]
